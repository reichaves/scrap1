# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://www.pythonscraping.com/pages/warandpeace.html")
bsObj = BeautifulSoup(html, "lxml")

# %%
nameList = bsObj.findAll("span", {"class":"green"})

# %%
for name in nameList:
    print(name.get_text())
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %% [markdown]
# ### Impõe limite

# %%
nameList2 = bsObj.findAll("span", {"class":"green"}, limit=3)

# %%
for name in nameList2:
    print(name.get_text())
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin

# %% [markdown]
# ### Seleciona tag com atributo

# %%
allText = bsObj.findAll(id="text")

# %%
print(allText[0].get_text())
# Out:
# "Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news."
#
# It was in July, 1805, and the speaker was the well-known Anna
# Pavlovna Scherer, maid of honor and favorite of the Empress Marya
# Fedorovna. With these words she greeted Prince Vasili Kuragin, a man
# of high rank and importance, who was the first to arrive at her
# reception. Anna Pavlovna had had a cough for some days. She was, as
# she said, suffering from la grippe; grippe being then a new word in
# St. Petersburg, used only by the elite.
#
# ...

# %% [markdown]
# ### Procura descendentes que sejam filhos (descendants traria bem mais resultados)

# %%
html = urlopen("http://www.pythonscraping.com/pages/page3.html")

# %%
bsObj = BeautifulSoup(html, "lxml")

# %%
for child in bsObj.find("table",{"id":"giftList"}).children:
    print(child)
# Out:
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
#
#
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# ...

# %% [markdown]
# ### Procura irmãos

# %%
for sibling in bsObj.find("table",{"id":"giftList"}).tr.next_siblings:
    print(sibling)
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# ...

# %% [markdown]
# ### Procura os pais da criança

# %%
from urllib.request import urlopen

# %%
from bs4 import BeautifulSoup

# %%
html = urlopen("http://www.pythonscraping.com/pages/page3.html")

# %%
bsObj = BeautifulSoup(html, "lxml")

# %%
print(bsObj.find("img", {"src":"../img/gifts/img1.jpg"}).parent.previous_sibling.get_text())
# Out:
# $15.00

# %% [markdown]
# ### Expressões regulares

# %%
from urllib.request import urlopen

# %%
from bs4 import BeautifulSoup

# %%
import re

# %%
images = bsObj.findAll("img", {"src":re.compile("\.\.\/img\/gifts/img.*\.jpg")})

# %%
for image in images: 
    print(image["src"])
# Out:
# ../img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# ../img/gifts/img6.jpg

# %% [markdown]
# ### Extraindo links

# %%
emendas = urlopen("http://www.camara.gov.br/proposicoesWeb/prop_emendas?idProposicao=2122076&subst=0")

# %%
bsObje =  BeautifulSoup(emendas, "lxml")

# %%
pdfs = bsObje.findAll("a", {"class":"rightIconified iconDetalhe linkDownloadTeor"})

# %%
for name in pdfs:
    print(name.get('href'))
# Out:
# prop_mostrarintegra?codteor=1532385&filename=EMC+1/2017+PL678716+%3D%3E+PL+6787/2016
# prop_mostrarintegra?codteor=1532386&filename=EMC+2/2017+PL678716+%3D%3E+PL+6787/2016
# prop_mostrarintegra?codteor=1532387&filename=EMC+3/2017+PL678716+%3D%3E+PL+6787/2016
# prop_mostrarintegra?codteor=1532388&filename=EMC+4/2017+PL678716+%3D%3E+PL+6787/2016
# prop_mostrarintegra?codteor=1532389&filename=EMC+5/2017+PL678716+%3D%3E+PL+6787/2016
# prop_mostrarintegra?codteor=1532390&filename=EMC+6/2017+PL678716+%3D%3E+PL+6787/2016
# prop_mostrarintegra?codteor=1532391&filename=EMC+7/2017+PL678716+%3D%3E+PL+6787/2016
# prop_mostrarintegra?codteor=1532392&filename=EMC+8/2017+PL678716+%3D%3E+PL+6787/2016
# prop_mostrarintegra?codteor=1532394&filename=EMC+9/2017+PL678716+%3D%3E+PL+6787/2016
# prop_mostrarintegra?codteor=1532395&filename=EMC+10/2017+PL678716+%3D%3E+PL+6787/2016
# prop_mostrarintegra?codteor=1532397&filename=EMC+11/2017+PL678716+%3D%3E+PL+6787/2016
# ...
